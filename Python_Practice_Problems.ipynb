# %% [markdown]
# <a href="https://colab.research.google.com/github/Aparna-981/ict-project/blob/main/Python_Practice_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  1.Write a Python program which accepts the radius of a circle from the user
# and compute the area.

# %%
import math
radius = int(input("enter the radius of circle : "))
Area = math.pi*radius**2
print(f"Area of the cirlce is {Area}")
# Out:
# enter the radius of circle : 4
# Area of the cirlce is 50.26548245743669

# %% [markdown]
# 2. Write a Python Program to accept the details of a student like name, roll
# number and mark and display it.

# %%
class student:
  def __init__(self,name,roll_no,mark):
    self.name=name
    self.roll_no=roll_no
    self.mark=mark
  def display(self):
    print(f" Name : {self.name} \n Roll No : {self.roll_no} \n Mark : {self.mark}")
name=input("Enter the name :")
roll_no=int(input("enter the roll number : "))
mark = int(input("Enter the mark : "))
details=student(name,roll_no,mark)
details.display()
# Out:
# Enter the name :Nisha
# enter the roll number : 302
# Enter the mark : 78
#  Name : Nisha
#  Roll No : 302
#  Mark : 78

# %% [markdown]
# Write a Python program to get the largest number from a list.

# %%
list1=[12,3,47,10]
number=max(list1)
print(f"{number} is the largest number")
# Out:
# 47 is the largest number

# %%
list1=input("enter the list of number").split()
list1=[int(num) for num in list1]
number=max(list1)
print(f"{number} is the largest number")
# Out:
# enter the list of number45 98 0 6 7 34
# 98 is the largest number

# %% [markdown]
# 4.  Given a range of first 10 numbers, write a Python program to iterate from
# start number to the end number and print the sum of the current number
# and previous number.

# %%
sum_of_number=0
for i in range(1,11):
  sum_of_number=i+(i-1)
  print(f" current number {i} previous number {i-1} sum: {sum_of_number}")
# Out:
#  current number 1 previous number 0 sum: 1
#  current number 2 previous number 1 sum: 3
#  current number 3 previous number 2 sum: 5
#  current number 4 previous number 3 sum: 7
#  current number 5 previous number 4 sum: 9
#  current number 6 previous number 5 sum: 11
#  current number 7 previous number 6 sum: 13
#  current number 8 previous number 7 sum: 15
#  current number 9 previous number 8 sum: 17
#  current number 10 previous number 9 sum: 19

# %% [markdown]
# 5. Write a Python program to print only those numbers which are divisible
# of 5.

# %%
number=input("enter the number : ").split()
number=[int(num) for num in number]
list1=[]
for i in number:
  if i%5==0:
   list1.append(i)
print(list1)
# Out:
# enter the number : 67 88 77 65 55 45 90
# [65, 55, 45, 90]

# %% [markdown]
# 6. Write a Python program to check whether a number is prime or not.
# Sample input: Enter the number: 3
# Sample output: 3 is a prime number.

# %%
number=int(input("enter the number : "))
if number>1:
  for i in range(2,number):
    if number%i==0:
      print(f"{number} is not prime number")
      break
  else:
      print(f"{number} is  prime number")
else:
  print(f"{number} is a not a prime number")
# Out:
# enter the number : 2
# 2 is  prime number

# %% [markdown]
# 7. Write a Python program to reverse a list using for loop.

# %%
list1=input("enter the number").split()
list1=[int(num) for num in list1]
list2=[]
for num in  range(len(list1)-1,-1,-1):
  list2.append(list1[num])
print(list2)
# Out:
# enter the number1 2 3 4 5
# [5, 4, 3, 2, 1]

# %% [markdown]
# 8. Write a Python program to print the following pattern.

# %%
num=4
for i in range(1,num+1):
  for j in range(i):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# 9. Write a Python program to find the maximum of three numbers

# %%
number=input("enter the number").split()
number=[int(num) for num in number]
print(f"highest number is {max(number)}")
# Out:
# enter the number78 90 65
# highest number is 90

# %%
num1=int(input("enter the number 1 :"))
num2=int(input("enter the number 2 :"))
num3=int(input("enter the number 3 :"))
if num1>=num2 and num1>=num3:
  print(f"{num1} is highest number")
elif num2>=num1 and num2>=num3:
  print(f"{num2} is highest number")
else:
  print(f"{num3} is highest number")
# Out:
# enter the number 1 :67
# enter the number 2 :123
# enter the number 3 :9
# 123 is highest number

# %% [markdown]
# 10.Write a Python program to construct the following pattern, using a
# nested for loop.

# %%
num=5
for i in range(1,num+1):
  for j in range(i):
    print("*",end="")
  print()
for k in range(num-1,0,-1):
  for l in range(k):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
