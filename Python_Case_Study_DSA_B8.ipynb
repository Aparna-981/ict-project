# %% [markdown]
# <a href="https://colab.research.google.com/github/Aparna-981/ict-project/blob/main/Python_Case_Study_DSA_B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Answer the following questions using only builtin Python datatypes and functions. Do not use Numpy or Scipy (i.e. No library imports allowed)

# %% [markdown]
# # Q1. Write a function that return the range (maximum and minimun) of a given list of numbers

# %%
list1=[7,3,9,6,2]
def display_range(num):
  maximum=max(list1)
  minimum=min(list1)
  ranges= maximum - minimum
  print(f"range(maximum,minimum) : {ranges}")
  return maximum , minimum
display_range(list1)
# Out:
# range(maximum,minimum) : 7
# (9, 2)

# %%
list1=[7,3,9,6,2]
def display_range(num):
  min_value=list1[0]
  max_value=list1[0]
  for i in list1:
    if i <= min_value:
      min_value=i
    if i >= max_value:
      max_value=i
  return( min_value,max_value)

range=display_range(list1)
print(f"range: {range}")
# Out:
# range: (2, 9)

# %% [markdown]
# ## Q2. Write function that returns mean value of a list of numbers

# %%
list1=[8,3,9,1,8]
def mean_list(num):
  total=0
  for i in list1:
    total+=i
  mean_value=(total)/ len(list1)
  return mean_value

mean_of_list=mean_list(list1)
print("mean : ",mean_of_list)
# Out:
# mean :  5.8

# %% [markdown]
# # Q3. Write a function that returns the median value of a list of numbers

# %%
list2=[9,3,5,8,1,10]
def median_list(num):
    list3=sorted(list2)
    print(list3)
    if len(list3)%2 !=0:
         median1=len(list3)//2
         median_value=list3[median1]
    else:
      median1=len(list3)//2-1
      median2=len(list3)//2
      median_value=(list3[median1]+list3[median2])//2
    return median_value
print("median of the list is : ",median_list(list1))
# Out:
# [1, 3, 5, 8, 9, 10]
# median of the list is :  6

# %% [markdown]
# ## Q4. Write a function to return the mod of a list of numbers, if no mod exists, it should return None. If more than one mod exist, return the mod values as list

# %%
list3=[2,7,9,6,2,0,1,2]
def mode_list(number):
   count=0
   for i in list3:
    if i in count:
      count[i]+=1
    else:
      count[i]=1
    return count
   max_count=0
   for j in count:
    if count > max_count:
            max_count = count

mode_list(list3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2161306012.py in <cell line: 0>()
#      13             max_count = count
#      14
# ---> 15 mode_list(list3)
#
# /tmp/ipython-input-2161306012.py in mode_list(number)
#       3    count=0
#       4    for i in list3:
# ----> 5     if i in count:
#       6       count[i]+=1
#       7     else:
#
# TypeError: argument of type 'int' is not iterable

# %% [markdown]
# ## Q5. Write function to compute a given percentile value (e.g. 90th percentile) of a list of numbers

# %% [markdown]
# # Q6. Write a function that returns the lower bound of a list of numbers

# %% [markdown]
# ## Q7. Write function to return any outliers from a given list of numbers, if no outliers present it should return None

# %% [markdown]
# ##Q8. Write a function to return standard deviation of a list of numbers

# %% [markdown]
# ## Q9. Write function to compute and return Z-score values of a list of numbers

# %% [markdown]
# ## Q10. Write a function to compute and return the Pearson correlation coefficient value of two list of numbers
